# %%
from DGraph import DGraph

# %%
myGraph = DGraph()

N = ["A", "B", "C", "D"]
E = [("A", "B", {"label":"test", "weight":1}),("B", "C", {"label":"test2", "weight":1}),("C", "D", {"label":"test3", "weight":1}),("D", "A", {"label":"test4", "weight":1})]

myGraph.add_multiple_nodes(N)
myGraph.add_multiple_edges(E)

# %%
myGraph.plot_weighted('value')
# Out:
# {}

# %%
myGraph.display()
